# %%
import json
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.neighbors import KNeighborsClassifier

# %%
pd.set_option('display.max_columns', None)
pd.set_option("max_rows", None)

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import Binarizer
from sklearn.preprocessing import minmax_scale
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import PowerTransformer

def Normalizing(data,execption=["class"]):
  methods={
      "MinMaxScaler":MinMaxScaler(feature_range=(0, 1)),
      "Normalizer":Normalizer(),
      "Binarizer":Binarizer(threshold=0.0),
      "RobustScaler":RobustScaler(quantile_range=(25, 75)),
      "yeoJohnson":PowerTransformer(method="yeo-johnson"),
      "boxCox":PowerTransformer(method="box-cox"),
      "MaxAbsScaler":MaxAbsScaler(),
      "uniform":QuantileTransformer(output_distribution="uniform"),
      "normal":QuantileTransformer(output_distribution="normal"),
      "StandardScaler":StandardScaler(),
  }
  selected_columns=data.columns.difference(execption)
  result={}

  for key, value in methods.items():
    data_sample=data.copy()
    if key=="boxCox" and (data_sample[selected_columns] <= 0).values.any():
      continue
    data_sample[selected_columns] = value.fit_transform(data_sample[selected_columns])
    result[key]=data_sample

  return result

# %%
data = pd.read_csv(f'PATH/DS1.csv.gz',compression='gzip',lineterminator='\n');
data=data.sample(frac=1).reset_index(drop=True)

# %%
classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)

# %%
for key,value in Normalizing(data).items():

  y = value['class']
  X = value.drop(['class'],axis=1)
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)
  classifier.fit(X_train, y_train)
  print(key)
  print("---------------------------------------------------------------------")
  print(classification_report(y_train, classifier.predict(X_train)))
  print(classification_report(y_test, classifier.predict(X_test)))
  print("---------------------------------------------------------------------\n\n")
# Out:
# MinMaxScaler
# ---------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#          bot       0.91      0.83      0.87     37163
#        human       0.89      0.94      0.91     52292
#
#     accuracy                           0.89     89455
#    macro avg       0.90      0.89      0.89     89455
# weighted avg       0.89      0.89      0.89     89455
#
#               precision    recall  f1-score   support
#
#          bot       0.86      0.78      0.82      4170
#        human       0.85      0.90      0.88      5770
#
#     accuracy                           0.85      9940
#    macro avg       0.85      0.84      0.85      9940
# weighted avg       0.85      0.85      0.85      9940
#
# ---------------------------------------------------------------------
#
#
# Normalizer
# ---------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#          bot       0.99      0.95      0.97     37178
#        human       0.96      0.99      0.98     52277
#
#     accuracy                           0.97     89455
#    macro avg       0.97      0.97      0.97     89455
# weighted avg       0.97      0.97      0.97     89455
#
#               precision    recall  f1-score   support
#
#          bot       0.98      0.94      0.96      4155
#        human       0.96      0.99      0.97      5785
#
#     accuracy                           0.97      9940
#    macro avg       0.97      0.96      0.97      9940
# weighted avg       0.97      0.97      0.97      9940
#
# ---------------------------------------------------------------------
#
#
# Binarizer
# ---------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#          bot       0.81      0.74      0.78     37148
#        human       0.83      0.88      0.85     52307
#
#     accuracy                           0.82     89455
#    macro avg       0.82      0.81      0.81     89455
# weighted avg       0.82      0.82      0.82     89455
#
#               precision    recall  f1-score   support
#
#          bot       0.81      0.73      0.77      4185
#        human       0.82      0.87      0.84      5755
#
#     accuracy                           0.81      9940
#    macro avg       0.81      0.80      0.81      9940
# weighted avg       0.81      0.81      0.81      9940
#
# ---------------------------------------------------------------------
#
#
# RobustScaler
# ---------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#          bot       0.96      0.93      0.95     37265
#        human       0.95      0.97      0.96     52190
#
#     accuracy                           0.95     89455
#    macro avg       0.96      0.95      0.95     89455
# weighted avg       0.96      0.95      0.95     89455
#
#               precision    recall  f1-score   support
#
#          bot       0.94      0.91      0.92      4068
#        human       0.94      0.96      0.95      5872
#
#     accuracy                           0.94      9940
#    macro avg       0.94      0.93      0.94      9940
# weighted avg       0.94      0.94      0.94      9940
#
# ---------------------------------------------------------------------
#
#
# yeoJohnson
# ---------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#          bot       0.99      0.95      0.97     37250
#        human       0.96      0.99      0.98     52205
#
#     accuracy                           0.97     89455
#    macro avg       0.98      0.97      0.97     89455
# weighted avg       0.97      0.97      0.97     89455
#
#               precision    recall  f1-score   support
#
#          bot       0.98      0.93      0.95      4083
#        human       0.95      0.99      0.97      5857
#
#     accuracy                           0.96      9940
#    macro avg       0.97      0.96      0.96      9940
# weighted avg       0.96      0.96      0.96      9940
#
# ---------------------------------------------------------------------
#
#
# MaxAbsScaler
# ---------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#          bot       0.91      0.83      0.87     37199
#        human       0.89      0.94      0.91     52256
#
#     accuracy                           0.89     89455
#    macro avg       0.90      0.89      0.89     89455
# weighted avg       0.89      0.89      0.89     89455
#
#               precision    recall  f1-score   support
#
#          bot       0.87      0.78      0.82      4134
#        human       0.85      0.92      0.88      5806
#
#     accuracy                           0.86      9940
#    macro avg       0.86      0.85      0.85      9940
# weighted avg       0.86      0.86      0.86      9940
#
# ---------------------------------------------------------------------
#
#
# uniform
# ---------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#          bot       0.98      0.92      0.95     37186
#        human       0.94      0.99      0.96     52269
#
#     accuracy                           0.96     89455
#    macro avg       0.96      0.95      0.96     89455
# weighted avg       0.96      0.96      0.96     89455
#
#               precision    recall  f1-score   support
#
#          bot       0.97      0.88      0.92      4147
#        human       0.92      0.98      0.95      5793
#
#     accuracy                           0.94      9940
#    macro avg       0.94      0.93      0.94      9940
# weighted avg       0.94      0.94      0.94      9940
#
# ---------------------------------------------------------------------
#
#
# normal
# ---------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#          bot       0.97      0.88      0.92     37135
#        human       0.92      0.98      0.95     52320
#
#     accuracy                           0.94     89455
#    macro avg       0.94      0.93      0.94     89455
# weighted avg       0.94      0.94      0.94     89455
#
#               precision    recall  f1-score   support
#
#          bot       0.95      0.84      0.89      4198
#        human       0.89      0.97      0.93      5742
#
#     accuracy                           0.91      9940
#    macro avg       0.92      0.90      0.91      9940
# weighted avg       0.92      0.91      0.91      9940
#
# ---------------------------------------------------------------------
#
#
# StandardScaler
# ---------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#          bot       0.90      0.85      0.88     37216
#        human       0.90      0.94      0.92     52239
#
#     accuracy                           0.90     89455
#    macro avg       0.90      0.89      0.90     89455
# weighted avg       0.90      0.90      0.90     89455
#
#               precision    recall  f1-score   support
#
#          bot       0.85      0.80      0.82      4117
#        human       0.86      0.90      0.88      5823
#
#     accuracy                           0.86      9940
#    macro avg       0.85      0.85      0.85      9940
# weighted avg       0.86      0.86      0.86      9940
#
# ---------------------------------------------------------------------

# %%
import json
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
# %matplotlib inline

# %%
pd.set_option('display.max_columns', None)
pd.set_option("max_rows", None)

# %%
data = pd.read_csv(f'PATH/implementation_sample_2.csv.gz',compression='gzip',lineterminator='\n');

# %%
DS1=pd.concat([data[data["class"]=="bot"],data[data["class"]=="human"].sample(60364)]);
DS1 = DS1.sample(frac=1).reset_index(drop=True)
DS2=pd.concat([data[data["class"]=="bot"],data[data["class"]=="human"].sample(60364)]);
DS2 = DS2.sample(frac=1).reset_index(drop=True)
DS3=pd.concat([data[data["class"]=="bot"],data[data["class"]=="human"].sample(60364)]);
DS3 = DS3.sample(frac=1).reset_index(drop=True)
DS4=pd.concat([data[data["class"]=="bot"],data[data["class"]=="human"].sample(60364)]);
DS4 = DS4.sample(frac=1).reset_index(drop=True)
DS5=pd.concat([data[data["class"]=="bot"],data[data["class"]=="human"].sample(60364)]);
DS5 = DS5.sample(frac=1).reset_index(drop=True)
DS6=pd.concat([data[data["class"]=="bot"],data[data["class"]=="human"].sample(60364)]);
DS6 = DS6.sample(frac=1).reset_index(drop=True)
DS7=pd.concat([data[data["class"]=="bot"],data[data["class"]=="human"].sample(60364)]);
DS7 = DS7.sample(frac=1).reset_index(drop=True)

# %%
y_1 = DS1['class']
X_1 = DS1.drop(['class'],axis=1)
X_train_1, X_test_1, y_train_1, y_test_1 = train_test_split(X_1, y_1, test_size=0.1)

y_2 = DS2['class']
X_2 = DS2.drop(['class'],axis=1)
X_train_2, X_test_2, y_train_2, y_test_2 = train_test_split(X_2, y_2, test_size=0.1)

y_3 = DS3['class']
X_3 = DS3.drop(['class'],axis=1)
X_train_3, X_test_3, y_train_3, y_test_3= train_test_split(X_3, y_3, test_size=0.1)

y_4 = DS4['class']
X_4 = DS4.drop(['class'],axis=1)
X_train_4, X_test_4, y_train_4, y_test_4 = train_test_split(X_4, y_4, test_size=0.1)

y_5 = DS5['class']
X_5 = DS5.drop(['class'],axis=1)
X_train_5, X_test_5, y_train_5, y_test_5 = train_test_split(X_5, y_5, test_size=0.1)

y_6 = DS6['class']
X_6 = DS6.drop(['class'],axis=1)
X_train_6, X_test_6, y_train_6, y_test_6 = train_test_split(X_6, y_6, test_size=0.1)

y_7 = DS7['class']
X_7 = DS7.drop(['class'],axis=1)
X_train_7, X_test_7, y_train_7, y_test_7 = train_test_split(X_7, y_7, test_size=0.1)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier


RF_1 = KNeighborsClassifier(n_neighbors = 3, metric = 'minkowski', p = 2)
RF_2 = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
RF_3 = KNeighborsClassifier(n_neighbors = 7, metric = 'minkowski', p = 2)
RF_4 = KNeighborsClassifier(n_neighbors = 9, metric = 'minkowski', p = 2)
RF_5 = KNeighborsClassifier(n_neighbors = 11, metric = 'minkowski', p = 2)
RF_6 = KNeighborsClassifier(n_neighbors = 13, metric = 'minkowski', p = 2)
RF_7 = KNeighborsClassifier(n_neighbors = 15, metric = 'minkowski', p = 2)

RF_1.fit(X_train_1, y_train_1)
RF_2.fit(X_train_2, y_train_2)
RF_3.fit(X_train_3, y_train_3)
RF_4.fit(X_train_4, y_train_4)
RF_5.fit(X_train_5, y_train_5)
RF_6.fit(X_train_6, y_train_6)
RF_7.fit(X_train_7, y_train_7)
# Out:
# KNeighborsClassifier(n_neighbors=15)

# %%
y_predict_train_1 = RF_1.predict(X_train_1)
print(classification_report(y_train_1, y_predict_train_1))
cm = confusion_matrix(y_train_1, y_predict_train_1)
sns.heatmap(cm, annot=True,fmt="d")
# Out:
#               precision    recall  f1-score   support
#
#          bot       0.88      0.87      0.88     35659
#        human       0.91      0.93      0.92     54341
#
#     accuracy                           0.90     90000
#    macro avg       0.90      0.90      0.90     90000
# weighted avg       0.90      0.90      0.90     90000

# %%
y_predict_train_2 = RF_2.predict(X_train_2)
print(classification_report(y_train_2, y_predict_train_2))
cm = confusion_matrix(y_train_2, y_predict_train_2)
sns.heatmap(cm, annot=True,fmt="d")
# Out:
#               precision    recall  f1-score   support
#
#          bot       0.85      0.84      0.84     35705
#        human       0.89      0.91      0.90     54295
#
#     accuracy                           0.88     90000
#    macro avg       0.87      0.87      0.87     90000
# weighted avg       0.88      0.88      0.88     90000

# %%
y_predict_train_3 = RF_3.predict(X_train_3)
print(classification_report(y_train_3, y_predict_train_3))
cm = confusion_matrix(y_train_3, y_predict_train_3)
sns.heatmap(cm, annot=True,fmt="d")
# Out:
#               precision    recall  f1-score   support
#
#          bot       0.84      0.82      0.83     35574
#        human       0.88      0.90      0.89     54426
#
#     accuracy                           0.87     90000
#    macro avg       0.86      0.86      0.86     90000
# weighted avg       0.87      0.87      0.87     90000

# %%
y_predict_train_4 = RF_4.predict(X_train_4)
print(classification_report(y_train_4, y_predict_train_4))
cm = confusion_matrix(y_train_4, y_predict_train_4)
sns.heatmap(cm, annot=True,fmt="d")
# Out:
#               precision    recall  f1-score   support
#
#          bot       0.83      0.80      0.82     35669
#        human       0.87      0.89      0.88     54331
#
#     accuracy                           0.86     90000
#    macro avg       0.85      0.85      0.85     90000
# weighted avg       0.86      0.86      0.86     90000

# %%
y_predict_train_5 = RF_5.predict(X_train_5)
print(classification_report(y_train_5, y_predict_train_5))
cm = confusion_matrix(y_train_5, y_predict_train_5)
sns.heatmap(cm, annot=True,fmt="d")
# Out:
#               precision    recall  f1-score   support
#
#          bot       0.82      0.80      0.81     35730
#        human       0.87      0.89      0.88     54270
#
#     accuracy                           0.85     90000
#    macro avg       0.85      0.84      0.84     90000
# weighted avg       0.85      0.85      0.85     90000

# %%
y_predict_train_6 = RF_6.predict(X_train_6)
print(classification_report(y_train_6, y_predict_train_6))
cm = confusion_matrix(y_train_6, y_predict_train_6)
sns.heatmap(cm, annot=True,fmt="d")
# Out:
#               precision    recall  f1-score   support
#
#          bot       0.82      0.79      0.80     35661
#        human       0.86      0.89      0.87     54339
#
#     accuracy                           0.85     90000
#    macro avg       0.84      0.84      0.84     90000
# weighted avg       0.85      0.85      0.85     90000

# %%
y_predict_train_7 = RF_7.predict(X_train_7)
print(classification_report(y_train_7, y_predict_train_7))
cm = confusion_matrix(y_train_7, y_predict_train_7)
sns.heatmap(cm, annot=True,fmt="d")
# Out:
#               precision    recall  f1-score   support
#
#          bot       0.81      0.78      0.80     35691
#        human       0.86      0.88      0.87     54309
#
#     accuracy                           0.84     90000
#    macro avg       0.84      0.83      0.83     90000
# weighted avg       0.84      0.84      0.84     90000

# %%
y_predict_1 = RF_1.predict(X_test_5)
cm = confusion_matrix(y_test_5, y_predict_1)
sns.heatmap(cm, annot=True,fmt="d")

# %%
y_predict_2 = RF_2.predict(X_test_5)
cm = confusion_matrix(y_test_5, y_predict_2)
sns.heatmap(cm, annot=True,fmt="d")

# %%
y_predict_3 = RF_3.predict(X_test_5)
cm = confusion_matrix(y_test_5, y_predict_3)
sns.heatmap(cm, annot=True,fmt="d")

# %%
y_predict_4 = RF_4.predict(X_test_5)
cm = confusion_matrix(y_test_5, y_predict_4)
sns.heatmap(cm, annot=True,fmt="d")

# %%
y_predict_5 = RF_5.predict(X_test_5)
cm = confusion_matrix(y_test_5, y_predict_5)
sns.heatmap(cm, annot=True,fmt="d")

# %%
y_predict_6 = RF_6.predict(X_test_5)
cm = confusion_matrix(y_test_5, y_predict_6)
sns.heatmap(cm, annot=True,fmt="d")

# %%
y_predict_7 = RF_7.predict(X_test_5)
cm = confusion_matrix(y_test_5, y_predict_7)
sns.heatmap(cm, annot=True,fmt="d")

# %%
print(classification_report(y_test_5, y_predict_1))
print(classification_report(y_test_5, y_predict_2))
print(classification_report(y_test_5, y_predict_3))
print(classification_report(y_test_5, y_predict_4))
print(classification_report(y_test_5, y_predict_5))
print(classification_report(y_test_5, y_predict_6))
print(classification_report(y_test_5, y_predict_7))
# Out:
#               precision    recall  f1-score   support
#
#          bot       0.81      0.86      0.83      3906
#        human       0.91      0.87      0.89      6094
#
#     accuracy                           0.87     10000
#    macro avg       0.86      0.87      0.86     10000
# weighted avg       0.87      0.87      0.87     10000
#
#               precision    recall  f1-score   support
#
#          bot       0.79      0.83      0.81      3906
#        human       0.89      0.86      0.87      6094
#
#     accuracy                           0.85     10000
#    macro avg       0.84      0.84      0.84     10000
# weighted avg       0.85      0.85      0.85     10000
#
#               precision    recall  f1-score   support
#
#          bot       0.79      0.82      0.80      3906
#        human       0.88      0.86      0.87      6094
#
#     accuracy                           0.84     10000
#    macro avg       0.84      0.84      0.84     10000
# ...

# %%
type(y_predict_2)
# Out:
# numpy.ndarray

# %%
output_prediction=list()
for index,value in enumerate(y_predict_1):
  if [y_predict_1[index],y_predict_2[index],y_predict_3[index],y_predict_4[index],y_predict_5[index],y_predict_6[index],y_predict_7[index]].count("bot")>3:
    output_prediction.append("bot")
  else:
    output_prediction.append("human")
output_prediction = np.array(output_prediction)
print(type(output_prediction))
print(len(output_prediction))
# Out:
# <class 'numpy.ndarray'>
# 10000

# %%
print(classification_report(y_test_5, output_prediction))
cm = confusion_matrix(y_test_5, output_prediction)
sns.heatmap(cm, annot=True,fmt="d")
# Out:
#               precision    recall  f1-score   support
#
#          bot       0.80      0.82      0.81      3906
#        human       0.88      0.87      0.88      6094
#
#     accuracy                           0.85     10000
#    macro avg       0.84      0.84      0.84     10000
# weighted avg       0.85      0.85      0.85     10000

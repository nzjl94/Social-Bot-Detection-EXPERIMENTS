# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np
import pandas as pd
import json

# %%
pd.set_option('display.max_columns', None)
pd.set_option("max_rows", None)

# %%
data = pd.read_csv(f'PATH/t-DS1.csv.gz',compression='gzip',lineterminator='\n');

data.drop(columns=["profile_background_image_url_https"], axis=1, inplace=True); # all values are False

data.rename(columns={
    'profile_banner_url':'profile_has_banner_url',
    'entities':'has_entities',
    '_location':'has_location',
    '_url':'has_url',
    'diff_days':'account_age'
}, inplace=True)

data.rename(columns=lambda x: x.lower(),inplace=True)



data = data.sample(frac=1).reset_index(drop=True)

data.to_csv(f'PATH/Dataset_Classified_With_BotometerV4.csv.gz', compression='gzip',index=False)


print(data.columns.tolist())
print(len(data))
print(len(data.columns))
data.head()

# %%
data = pd.read_csv(f'PATH/DS1.csv.gz',compression='gzip',lineterminator='\n');

data.drop(columns=["profile_background_image_url_https"], axis=1, inplace=True); # all values are False

data.rename(columns={
    'profile_banner_url':'profile_has_banner_url',
    'entities':'has_entities',
    '_location':'has_location',
    '_url':'has_url',
    'diff_days':'account_age'
}, inplace=True)

data.rename(columns=lambda x: x.lower(),inplace=True)



data = data.sample(frac=1).reset_index(drop=True)

data.to_csv(f'PATH/Dataset_Classified_With_BotometerLite.csv.gz', compression='gzip',index=False)


print(data.columns.tolist())
print(len(data))
print(len(data.columns))
data.head()

# %%
import numpy as np
import pandas as pd
import json
import glob
import zipfile
import gzip
import shutil
import os
import csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
fileCounter=1;
archive = zipfile.ZipFile('PATH/RawData.zip', 'r')
for index,f in enumerate(reversed(archive.namelist())):
    if f.endswith("/") or index==0:
        if index!=0:
          file_object.write("]")
          file_object.close()
          with open(f"PATH/data{fileCounter}.json", 'rb') as f_in:
            with gzip.open(f"PATH/data{fileCounter}.json.gz", 'wb') as f_out:
              shutil.copyfileobj(f_in, f_out)

          if os.path.exists(f"PATH/data{fileCounter}.json"):
            os.remove(f"PATH/data{fileCounter}.json")
          else:
            print("The file does not exist")

          fileCounter=fileCounter+1;


        file_object = open(f"PATH/data{fileCounter}.json", 'a')
        file_object.write("[")
    else:
        print(f)
        with archive.open(f,mode='r') as file:
            for line in file:
                file_object.write(line.rstrip().decode('UTF-8')+",")

# %%
fileCounter=1;
archive = zipfile.ZipFile('PATH/RawData.zip', 'r')
for index,f in enumerate(reversed(archive.namelist())):
    if f.endswith("/") or index==0:
        if index!=0:
          #file_object.write("]")
          # file_object.close()
          # with open(f"PATH/data{fileCounter}.json", 'rb') as f_in:
          #   with gzip.open(f"PATH/data{fileCounter}.json.gz", 'wb') as f_out:
          #     shutil.copyfileobj(f_in, f_out)

          # if os.path.exists(f"PATH/data{fileCounter}.json"):
          #   os.remove(f"PATH/data{fileCounter}.json")
          # else:
          #   print("The file does not exist")

          fileCounter=fileCounter+1;


        # file_object = open(f"PATH/data{fileCounter}.json", 'a')
        # file_object.write("[")
    else:
        print(f)
        with archive.open(f,mode='r') as file:
            for line in file:
              print(json.loads(line.rstrip().decode('UTF-8'))["user"])
              break

# %%
fileCounter=1;
archive = zipfile.ZipFile('PATH/RawData.zip', 'r')
for index,f in enumerate(reversed(archive.namelist())):
    if f.endswith("/") or index==0:
        if index!=0:
          file_object.close()
          with open(f"PATH/data{fileCounter}", 'rb') as f_in:
            with gzip.open(f"PATH/data{fileCounter}.gz", 'wb') as f_out:
              shutil.copyfileobj(f_in, f_out)

          if os.path.exists(f"PATH/data{fileCounter}"):
            os.remove(f"PATH/data{fileCounter}")
          else:
            print("The file does not exist")
          fileCounter=fileCounter+1;
        file_object = open(f"PATH/data{fileCounter}", 'a')
    else:
        print(f)
        with archive.open(f,mode='r') as file:
            for line in file:
                file_object.write(json.dumps(json.loads(line.rstrip().decode('UTF-8'))["user"])+",")

# %%
fileCounter=1;
archive = zipfile.ZipFile('PATH/RawData.zip', 'r')
resultList=[]
for index,f in enumerate(reversed(archive.namelist())):
    if f.endswith("/") or index==0 or index==2:
        if index!=0:
          # file_object.close()
          # with open(f"PATH/data{fileCounter}.csv", 'rb') as f_in:
          #   with gzip.open(f"PATH/data{fileCounter}.csv.gz", 'wb') as f_out:
          #     shutil.copyfileobj(f_in, f_out)

          # if os.path.exists(f"PATH/data{fileCounter}.csv"):
          #   os.remove(f"PATH/data{fileCounter}.csv")
          # else:
          #   print("The file does not exist")
          fileCounter=fileCounter+1;
        # file_object = open(f"PATH/data{fileCounter}.csv", 'a')
    else:
        print(f)          
        with archive.open(f,mode='r') as file:
            for line in file:
              resultList= list(set(resultList) | set(list(json.loads(line.rstrip().decode('UTF-8'))["user"].keys())))

# %%
fileCounter=1;
archive = zipfile.ZipFile('PATH/RawData.zip', 'r')
for index,f in enumerate(reversed(archive.namelist())):
    if f.endswith("/") or index==0:
        if index!=0:
          file_object.close()
          with open(f"PATHdata{fileCounter}.csv", 'rb') as f_in:
            with gzip.open(f"PATH/data{fileCounter}.csv.gz", 'wb') as f_out:
              shutil.copyfileobj(f_in, f_out)

          if os.path.exists(f"PATH/data{fileCounter}.csv"):
            os.remove(f"PATH/data{fileCounter}.csv")
          else:
            print("The file does not exist")
          fileCounter=fileCounter+1;
        file_object = open(f"PATH/data{fileCounter}.csv", 'a')
    else:
        print(f)
        fieldnames = []
        if len(fieldnames)<=0:
          writer = csv.DictWriter(file_object, fieldnames=resultList)

          
        with archive.open(f,mode='r') as file:
            for line in file:
              writer.writerow(json.loads(line.rstrip().decode('UTF-8'))["user"])

# %%
file_object = open(f"PATH/final_version.csv", 'a')
writer = csv.DictWriter(file_object, fieldnames=resultList)

archive = zipfile.ZipFile('PATH/RawData.zip', 'r')
for index,f in enumerate(reversed(archive.namelist())):
    if f.endswith("/"):
      pass
    else:
        print(f)
        with archive.open(f,mode='r') as file:
            for line in file:
              writer.writerow(json.loads(line.rstrip().decode('UTF-8'))["user"])
file_object.close()
file_object = open(f"PATH/final_version.csv","w")

# %%
result = pd.read_csv(f'PATH/final_version.csv.gz',compression='gzip',lineterminator='\n');
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (33,43) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
len(result)
# Out:
# 3137420

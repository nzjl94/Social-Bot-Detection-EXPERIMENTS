# %%
import numpy as np
import pandas as pd
import json
import glob
import zipfile
import gzip
import shutil
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pd.set_option('display.max_columns', None)
pd.set_option("max_rows", None)

# %%
data = pd.read_csv(f'PATH/createdAtTwitter.csv.gz',compression='gzip',lineterminator='\n');

# %%
data.columns = ["id","user_created_at"]
print(len(data))
data=data.drop_duplicates('id', keep="last")
print(len(data))
# Out:
# 16406512
# 3138883

# %%
data.head()
# Out:
#                      id                   user_created_at
# 14            570552536  Mon Nov 09 21:20:13 +0000 2020\r
# 31           4908236249  Mon Nov 09 21:20:00 +0000 2020\r
# 41  1325902676228530177  Mon Nov 09 21:19:53 +0000 2020\r
# 47  1307571746711703554  Mon Nov 09 21:19:47 +0000 2020\r
# 68  1325252304921010176  Mon Nov 09 21:19:36 +0000 2020\r

# %%
result = pd.read_csv(f'PATH/metaDataFullColumnFullRow_2022_05_16.csv.gz',compression='gzip',lineterminator='\n');
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (19,29) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
final_result=pd.merge(result,data,on='id',how='inner')

# %%
print(len(final_result))
final_result.head(10)
# Out:
# 3138882
#    Unnamed: 0                      url  listed_count  lang  statuses_count  \
# 0       20059  https://t.co/KfVFls7SBf            40   NaN            8160
# 1       20076                      NaN             0   NaN            6423
# 2       20086                      NaN             0   NaN              12
# 3       20092                      NaN             0   NaN              38
# 4       20113                      NaN             0   NaN             191
# 5       20117                      NaN             1   NaN           50243
# 6       20126  https://t.co/F04Nha2MVu            33   NaN           24487
# 7       20185  https://t.co/vTuVniClTF            15   NaN            2624
# 8       20194                      NaN             2   NaN             321
# 9       20208   http://t.co/Pq6MwSGXhe             1   NaN             134
#
#    favourites_count                       profile_background_image_url  \
# ...

# %%
final_result.drop(columns=['Unnamed: 0'], axis=1, inplace=True);
final_result.to_csv(f'PATH/metaDataFullColumnFullRowWithTweetDate_2022_05_16.csv.gz', compression='gzip')

# %%
final_result.head()
# Out:
#                        url  listed_count  lang  statuses_count  \
# 0  https://t.co/KfVFls7SBf            40   NaN            8160
# 1                      NaN             0   NaN            6423
# 2                      NaN             0   NaN              12
# 3                      NaN             0   NaN              38
# 4                      NaN             0   NaN             191
#
#    favourites_count                       profile_background_image_url  \
# 0              6324  http://abs.twimg.com/images/themes/theme10/bg.gif
# 1             15385   http://abs.twimg.com/images/themes/theme1/bg.png
# 2                 3                                                NaN
# 3                17                                                NaN
# 4                16                                                NaN
#
#   profile_sidebar_fill_color                   id  \
# 0                     000000            570552536
# 1                     000000           4908236249
# ...
